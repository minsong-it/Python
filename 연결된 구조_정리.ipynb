# %% [markdown]
# # 연결된 구조

# %% [markdown]
# 단순 연결리스트 => 자바의 배열(Array 개념과 유사)
#
# <push 이해>.
#
# 스택(후입선출)이므로 처음 쌓으면
# top = (None)
#
# 스택은 데이터의 모임이 아닌, 주소값의 모임이라는 걸 명심, 주소값이 쌓이고 가장 최근에 쌓은 값이 top으로 갱신되는 개념
#
# 두번째로 데이터를 추가할 경우
# n = ( top )
# ==  n = (0, None), 0이라는 값이 쌓임
#
# == top = n, top에 n값을 대입해서 가장 최근에 쌓인 데이터를 top으로 갱신
#
# ...
#
# 스택 = (...3, 2, 1, None) 이런식으로 데이터 주소값이 쌓임, 스택의 각 값은 데이터 위치를 가지는 주소값

# %%
# 단순연결리스트, stack활용

class Node : 
  def __init__(self, elem, link=None):
    self.data = elem
    self.link = link

class linkedStack :
  def __init__(self):0
    self.top = None
  
  def isEmpty(self):
    return self.top == None
  
  def push(self, e):
    if not self.isEmpty() :
      nod = Node(e, self.top)
      self.top = nod

  def pop(self):
    if not self.isEmpty() :
      nod = self.top
      self.top = nod.link
      return nod.data

  def clear(self):
    self.top = None
  
  #다시~
  def peek(self):
    if not self.isEmpty():
      return self.top.data
  
  def size(self):
    '''link의 개수를 통해 size 확인'''
    nod = self.top
    count = 0
    while not nod == None:
      nod = nod.link
      count += 1
      return count

    '''
    실패~
    nod = Node()
    link_count = nod.link
    return link_count.size
    '''

# %%
#단순연결리스트, list활용

class Node:
  def __init__(self, elem, link=None):
    self.data = elem
    self.link = link

class linkedList:
  def __init__(self):
    '''ref는 레퍼런스값'''
    self.ref = None
  
  def insert(self,pos, e):
    '''pos위치에 e를 삽입'''

    
  def isEmpty(self):
    '''리스트가 비어있는지 검사'''
    return self.ref == None

  def getNode(self, pos):
    # 노드에서 pos위치 요소를 찾는과정이 필요, 그 전 값의 link가 필요
    if pos < 0 : return None

    while pos > 0 :
      node = self.
      

  def getEntry(self, pos):
    '''pos에 위치한 값 반환'''
    nod = Node()

    if nod.link == self.ref:
      return nod.data
    
  
  def delete(self, pos):
    '''pos위치에 있는 요소를 꺼내고 반환'''
    e = self.getEntry(pos)
    # 요소를 삭제하는 과정 => 어떤 값으로 덮어씌워야 함?

  def size(self):
    '''요소 개수 반환'''
    nod = self.ref
    count = 0
    while not nod == None:
      nod = nod.link
      count += 1
      return count
  
  def clear(self):
    self.ref = None

  def find(self, item):
    if s

# %%
'''
실패
  def insert(self,pos, e):
    """pos위치에 e를 삽입"""
    nod = Node(e,pos)
    self.ref = nod.link

  def getNode(self, pos):
    nod = Node()
    if nod.link == None: return None
    while node.link != None :
      node.link =  => 여기서 pos값과 link값이 일치해야한다고 보는데 그걸 매치할 수 없음
'''
